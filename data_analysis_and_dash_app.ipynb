# %% [markdown]
# **Data Analysis**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
from dash import Dash, dash_table
from dash import dash_table
import dash_table_experiments as dt

# %%
df=pd.read_csv('books_scraped.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head(5)
# Out:
#                                    title availability   price  \
# 0                   A Light in the Attic      Instock  £51.77
# 1                     Tipping the Velvet      Instock  £53.74
# 2                             Soumission      Instock  £50.10
# 3                          Sharp Objects      Instock  £47.82
# 4  Sapiens: A Brief History of Humankind      Instock  £54.23
#
#                                                  url               ups  \
# 0  https://books.toscrape.com/catalogue/a-light-i...  a897fe39b1053632
# 1  https://books.toscrape.com/catalogue/tipping-t...  90fa61229261140a
# 2  https://books.toscrape.com/catalogue/soumissio...  6957f44c3847a760
# 3  https://books.toscrape.com/catalogue/sharp-obj...  e00eb4fd7b871a48
# 4  https://books.toscrape.com/catalogue/sapiens-a...  4165285e1663650f
#
#              category
# 0              Poetry
# 1  Historical Fiction
# 2             Fiction
# 3             Mystery
# 4             History

# %%
top_categories=pd.DataFrame(df['category'].value_counts().head(15)).sort_values(by='category',ascending=True)
fig1 = px.bar(top_categories, orientation='h', title='Top 15 categories by total number of books')
fig1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7c7c685b-8e4b-4d5e-bc03-ba64a549c264" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c7c685b-8e4b-4d5e-bc03-ba64a549c264")) {                    Plotly.newPlot(                        "7c7c685b-8e4b-4d5e-bc03-ba64a549c264",                        [{"alignmentgroup":"True","hovertemplate":"variable=category<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"category","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"category","offsetgroup":"category","orientation":"h","showlegend":true,"textposition":"auto","x":[18,19,19,26,29,30,32,35,48,54,65,67,75,110,152],"xaxis":"x","y":["History","Poetry","Classics","Historical Fiction","Childrens","Food and Drink","Mystery","Romance","Fantasy","Young Adult","Fiction","Add a comment","Sequential Art","Nonfiction","Default"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"lin ...

# %%
fig2 = px.box(df, x='category',y="price", orientation='v', title='Price distrivution by category')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f0cb73c1-6bc3-46ce-974c-ddaf9d838746" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0cb73c1-6bc3-46ce-974c-ddaf9d838746")) {                    Plotly.newPlot(                        "f0cb73c1-6bc3-46ce-974c-ddaf9d838746",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Poetry","Historical Fiction","Fiction","Mystery","History","Young Adult","Business","Default","Default","Poetry","Default","Poetry","Young Adult","Sequential Art","Music","Music","Poetry","Science Fiction","Politics","Travel","Thriller","Music","Food and Drink","Romance","Romance","Childrens","Default","Default","Nonfiction","Art","Spirituality","Nonfiction","Thriller","Childrens","Philosophy","Default","Default","Mystery","Thriller","Poetry","Poetry","Nonfiction","Fiction","Nonfiction","New Adult","Contemporary","Fiction","Poetry","Nonfiction","Fantasy","History","Sequential Art","Nonfiction","Sequential Art","Fiction","Add a comment","Childrens","Food and Drink","Mystery","Young Adult","Sequential Art","Fiction","Science","Add a comment","Nonfiction","Default","Nonfiction","Nonfiction","Philosophy","Health","Add a comment","History","Spirituality","Nonfiction","Default","Horror","Fantasy","Sequential Art","Nonfiction","Sequential Art","Sequential Art","Fantasy","Sequential Art","History","Sequential Art","Sequential Art","Sequential Art","Self Help","Add a comment","Young Adult","Food and Drink","Fantasy","Food and Drink","Sequential Art","Sequential Art","Sequential Art","Food and Drink","Add a comment","Science Fiction","Nonfiction","Science","Sequential Art","Sequential Art","Self Help","Romance","Sequential Art","Historical Fiction","Romance","Romance","Nonfiction","Religion","Sequential Art","Fantasy","Sequential Art","Sequential Art","Nonfiction","Young Adult","Default","Sequential Art","Fantasy","Nonfiction","Default","Default","Mystery","Historical Fiction","Young Adult","Fantasy","Christian","Religion","Science Fiction","Fiction","Default","Fantasy","History","Default","Childrens","Romance","Fiction","Business","Philosophy","Sequential Art","Default","Fiction","Default","Science Fiction","Nonfiction","Nonfiction","Food and Drink","Mystery","New Adult","New Adult","Food and Drink","Crime","Default","Historical Fiction","Fantasy","Default","Nonfiction","Default","Food and Drink","Default","Nonfiction","Default","Autobiography","Business","Romance","Romance","Science Fiction","Nonfiction","Business","Add a comment","Default","Young Adult","Default","Christian Fiction","Default","Poetry","Young Adult","Poetry","Historical Fiction","Add a comment","Default","Biography","Childrens","Young Adult","Default","Womens Fiction","Fantasy","Default","Travel","Young Adult","Horror","Default","Fiction","Sequential Art","Default","Default","Default","Romance","Food and Drink","Erotica","Nonfiction","Christian Fiction","Spirituality","Nonfiction","Nonfiction","Default","Sequential Art","Sequential Art","Default","Default","Default","Cultural","Default","Nonfiction","History","Thriller","Sequential Art","Young Adult","Politics","Nonfiction","Nonfiction","Sequential Art","Childrens","Default","Young Adult","Default","Childrens","Sequential Art","Young Adult","Nonfiction","Default","Add a comment","Romance","Fiction","Fiction","Fantasy","Default","Add a comment","Default","Default","Historical Fiction","Psychology","Humor","Horror","Nonfiction","Mystery","Add a comment","Fantasy","Food and Drink","Thriller","Fiction","Add a comment","Young Adult","Fantasy","Nonfiction","Thriller","Myste ...

# %%
most_expensive=df.sort_values(by='price', ascending=False).head(5)
most_expensive
# Out:
#                                   title availability   price  \
# 648  The Perfect Play (Play by Play #1)      Instock  £59.99
# 617   Last One Home (New Beginnings #1)      Instock  £59.98
# 860    Civilization and Its Discontents      Instock  £59.95
# 560      The Barefoot Contessa Cookbook      Instock  £59.92
# 366           The Diary of a Young Girl      Instock  £59.90
#
#                                                    url               ups  \
# 648  https://books.toscrape.com/catalogue/the-perfe...  9cc207168a03470d
# 617  https://books.toscrape.com/catalogue/last-one-...  07e6810fd3236bda
# 860  https://books.toscrape.com/catalogue/civilizat...  396385e3de5d18c3
# 560  https://books.toscrape.com/catalogue/the-baref...  6478ccb4416e6a5d
# 366  https://books.toscrape.com/catalogue/the-diary...  54fc03f1e1d355db
#
#            category
# 648         Romance
# 617         Fiction
# 860      Psychology
# 560  Food and Drink
# 366      Nonfiction

# %%
least_expensive=df.sort_values(by='price', ascending=True).head(5)
least_expensive
# Out:
#                                                  title availability   price  \
# 638                         An Abundance of Katherines      Instock  £10.00
# 501                              The Origin of Species      Instock  £10.01
# 716  The Tipping Point: How Little Things Can Make ...      Instock  £10.02
# 84                                            Patience      Instock  £10.16
# 302                               Greek Mythic History      Instock  £10.23
#
#                                                    url               ups  \
# 638  https://books.toscrape.com/catalogue/an-abunda...  f36d24c309e87e5b
# 501  https://books.toscrape.com/catalogue/the-origi...  0345872b14f9e774
# 716  https://books.toscrape.com/catalogue/the-tippi...  224fa77d4b248046
# 84   https://books.toscrape.com/catalogue/patience_...  9429b4d59c537af5
# 302  https://books.toscrape.com/catalogue/greek-myt...  f201f263d8c23f97
#
#            category
# 638     Young Adult
# 501         Science
# 716   Add a comment
# 84   Sequential Art
# 302         Default

# %% [markdown]
# **Dash Application**

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    html.H1("Analysis of Webscraped Books"),
    html.H4("Our team worked on a Book Scraper project. First of all, we decided to implement web scraping with the Python library BeautifulSoap to collect information efficiently. Our next step was inspecting the page of the provided book library. We extracted such book's parameters as Name, Availability, Price, URL, UPS, and Category in the 'div' tag. After this, in the Python file, we coded steps for extracting data and storing results into a CSV file. Furthermore, our main purpose is to present our work in a convenient way for users. Exactly that's why we also analyzed provided data and created several graphs."),
    html.H4("In the first figure top 15 books categories were presented. Ignorining 'default' category, we can see that the highest numnber of books are in nonficntion catgeory."),
    dcc.Graph(figure=fig1),
    html.H4("But what might be the reason why there is biggest supply of non-fiction books? Might it be the price? To address this question, let;s take a look of price distribution for different book categories. We can clearly see that non-fiction books are not the cheapest ones. The Spirtuality books seem to have the 'cheapest' curve, whereas Sports and Games seem to be the most expensive ones. "),
    dcc.Graph(figure=fig2),
    html.H4("To go even more deeper than categories, we can also have information about the titles of the most expensive and least expesnive book. The most expensice books are:"),
    dash_table.DataTable(most_expensive.to_dict('records'),[{"name": i, "id": i} for i in df.columns], id='tbl'),
    html.H4("There are 5 the cheapest books:"),
    dash_table.DataTable(least_expensive.to_dict('records'),[{"name": i, "id": i} for i in df.columns], id='tbl'),


])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash app running on:
